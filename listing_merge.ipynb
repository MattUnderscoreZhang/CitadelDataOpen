# %%
import numpy as np
import pandas as pd

# %%
calendar=pd.read_csv("calendar.csv")

# %%
calendar[0:3]
# Out:
#    listing_id        date available   price metro_area
# 0        2515  2018-03-05         t  $69.00        NYC
# 1        2515  2018-03-04         t  $69.00        NYC
# 2        2515  2018-03-03         t  $69.00        NYC

# %%
#set(calendar['metro_area'])
set(listings['metropolitan'])
# Out:
# {'NYC', 'boston', 'chicago', 'dc', 'denver'}

# %%
listings=pd.read_csv("listings.csv")
real_estate=pd.read_csv("real_estate.csv")
econ_state=pd.read_csv("econ_state.csv")

# %%
listings.head()
# Out:
#    accommodates                                          amenities  \
# 0           2.0  {"Cable TV","Wireless Internet","Air condition...
# 1           4.0  {TV,Internet,"Wireless Internet","Air conditio...
# 2           4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 3           3.0  {TV,Internet,"Wireless Internet","Air conditio...
# 4           4.0  {Internet,"Wireless Internet","Air conditionin...
#
#    availability_30  bathrooms  bed_type  bedrooms  beds cancellation_policy  \
# 0               24        1.0  Real Bed       1.0   1.0            moderate
# 1               30        1.0  Real Bed       1.0   1.0            flexible
# 2               30        3.0  Real Bed       3.0   3.0              strict
# 3                8        1.0  Real Bed       1.0   1.0              strict
# 4               17        1.0  Real Bed       1.0   1.0            moderate
#
#                city  has_availability   ...     review_scores_checkin  \
# ...

# %%
#listings[0:1]
#calendar.shape
#listings.shape
#cal_list.shape
#list_econ.shape
#real_estate.shape
#real_estate.dtypes

# %%
#listings.loc[listings['id']==7949480,["state"]]=99

# %%
#cal_list=pd.merge(listings,calendar,how="inner",left_on='id',right_on='listing_id')
list_econ=pd.merge(listings,econ_state.iloc[:,[0,41,42,43,44,45,46,47]],how="left",left_on='state',right_on="state")

# %%
colrange=[i for i in range(244,262)]
colrange.extend([0,1])
list_econ['zipcode']
list_econ_real=pd.merge(list_econ,real_estate.iloc[:,colrange],how="left",left_on="zipcode",right_on='zipcode')

# %%
list_econ_real.iloc[:,27:40]
# Out:
#       weekly_price zipcode  2015Q1_gdp  2015Q2_gdp  2015Q3_gdp  2015Q4_gdp  \
# 0              NaN   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 1              NaN   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 2              NaN   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 3          $775.00   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 4          $350.00   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 5          $550.00   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 6              NaN   10464   1412184.0   1431902.0   1450379.0   1439659.0
# 7              NaN   10467   1412184.0   1431902.0   1450379.0   1439659.0
# 8              NaN   10469   1412184.0   1431902.0   1450379.0   1439659.0
# 9              NaN   10469   1412184.0   1431902.0   1450379.0   1439659.0
# 10         $350.00   10469   1412184.0   1431902.0   1450379.0   1439659.0
# ...

# %%
#real_estate.iloc[0:3,colrange]
real_estate.iloc[0:3,colrange]
# Out:
#    2016-01    2016-02    2016-03    2016-04    2016-05  2016-06  2016-07  \
# 0  1007800  1031000.0  1055800.0  1063500.0  1062900.0  1080800  1109400
# 1   311800   313100.0   315000.0   317000.0   317500.0   317500   317900
# 2   393200   397200.0   400500.0   404000.0   403500.0   401400   400100
#
#    2016-08  2016-09  2016-10  2016-11    2016-12  2017-01  2017-02  2017-03  \
# 0  1132500  1137500  1137700  1152700  1156000.0  1140200  1130000  1131900
# 1   318600   318200   318100   318800   320200.0   320800   322000   323800
# 2   400700   401900   406000   414100   417800.0   417400   418400   414100
#
#    2017-04  2017-05  2017-06  type  zipcode
# 0  1149600  1198400  1247000  ZHVI    10025
# 1   326100   327800   329100  ZHVI    60657
# 2   404100   406400   415500  ZHVI    60614
